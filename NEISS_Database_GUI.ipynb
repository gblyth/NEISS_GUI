# %%
import urllib
import requests
import http.cookiejar
from bs4 import BeautifulSoup as bs

headers = {
    'HTTP_USER_AGENT': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36',
    'HTTP_ACCEPT': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'Content-Type': 'application/x-www-form-urlencoded'
}

url="https://uchicago.box.com/v/NEISS1998"
url_get=requests.get(url, headers)

soup = bs(url_get.content, 'html.parser')
#soup = bs(url_get.content, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-resin-client="web">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="noindex, nofollow" name="robots"/>
#   <title>
#    Box
#   </title>
#   <link href="https://cdn01.boxcdn.net/fonts/1.0.2/lato/Lato-woff.css" rel="stylesheet"/>
#   <link href="https://cdn01.boxcdn.net/enduser/app.31d16c663b.css" rel="stylesheet"/>
#   <link href="https://cdn01.boxcdn.net/_assets/img/favicons/apple-touch-icon-57x57-fLlEpj.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="https://cdn01.boxcdn.net/_assets/img/favicons/apple-touch-icon-60x60-Uv0qzu.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="https://cdn01.boxcdn.net/_assets/img/favicons/apple-touch-icon-72x72-7aVqne.png" rel="apple-touch-icon" sizes="72x72"/>
# ...

# %%
import urllib
import requests
import http.cookiejar
from bs4 import BeautifulSoup as bs


url='https://api.cpsc.gov/opendataApi/neissdata/list?startDate=2000-02-02&api_key=uN3EUa1Evc6Yfi16IzD3X2hjdg4QPs8ZmSz9PnHi'
#response=urllib.request.urlretrieve(url,'rss.xml')
response=requests.get(url)
#message=response[1]
print(type(response))
print(response)

soup2=bs(response.content, 'lxml')
print(soup2)
#data=response[1].read()
cpsccase=soup2.find_all('cpsccase')
print(len(cpsccase),"\nCases:\n")
for row in cpsccase:
    print(row)
# Out:
# <class 'requests.models.Response'>
# <Response [200]>
# ...

# %%
data=soup2.XML_FORMATTERS

print(type(data))
print(len(data))
print(data)
import xml.etree.ElementTree as ET

with open('rss.xml','wb') as xml:
    xml.write(data)

tree=ET.parse('rss.xml')
root=tree.getroot()
for child in root:
    print(child)
# Out:
# <class 'bs4.BeautifulSoup'>
# 1
# ...

# %%
import urllib
import requests
from tkinter import *
from tkinter.filedialog import askdirectory

class NEISS_Data_Requester(object):
    def __init__(self, master):
        self.years=[]
        self.data=[]
        self.master=master
        self.var1=IntVar()
        self.var2=IntVar()
        self.var3=IntVar()
        self.var4=IntVar()
        self.var5=IntVar()
        self.var6=IntVar()
        self.var7=IntVar()
        self.var8=IntVar()
        self.var9=IntVar()
        self.var10=IntVar()
        self.var11=IntVar()
        self.var12=IntVar()
        self.var13=IntVar()
        self.var14=IntVar()
        self.var15=IntVar()
        self.var16=IntVar()
        self.var17=IntVar()
        self.var18=IntVar()
        self.var19=IntVar()
        self.var20=IntVar()
        self.data_years=StringVar()
        self.data_years.set("Years of Data Loaded=\nNone")
        self.data_years=StringVar()
        self.data_years.set("Years of Data Loaded=\nNone")
        self.data_loaded=False
        self.file_to_dl=False
        self.load_str=StringVar()
        self.load_str.set("Datasets Loaded="+str(self.data_loaded))
        self.dl_str=StringVar()
        self.dl_str.set("File Ready To Download="+str(self.file_to_dl))
        self.entry1=StringVar()
        self.entry1.set("(MM/DD/YYYY)or(MM/DD/YYYY-MM/DD/YYYY)")
        self.entry2=StringVar()
        self.entry2.set("singlular(#) or range(#-#)")
        self.entry3=StringVar()
        self.entry3.set("")
        self.entry4=StringVar()
        self.entry4.set("")
        self.entry5=StringVar()
        self.entry5.set("")
        self.entry6=StringVar()
        self.entry6.set("")
        self.entry7=StringVar()
        self.entry7.set("")
        self.entry8=StringVar()
        self.entry8.set("")
        self.entry9=StringVar()
        self.entry9.set("")
        self.entry10=StringVar()
        self.entry10.set("")
        self.entry11=StringVar()
        self.entry11.set("")
        self.entry12=StringVar()
        self.entry12.set("")
        self.entry13=StringVar()
        self.entry13.set("")
        self.entry14=StringVar()
        self.entry14.set("")
        self.entry15=StringVar()
        self.entry15.set("")
        self.entry16=StringVar()
        self.entry16.set("")
        self.entry17=StringVar()
        self.entry17.set("")
        
    def varStates(self):
        self.years=[("1998", self.var1.get()),
             ("1999", self.var2.get()),
             ("2000", self.var3.get()),
             ("2001", self.var4.get()),
             ("2002", self.var5.get()),
             ("2003", self.var6.get()),
             ("2004", self.var7.get()),
             ("2005", self.var8.get()),
             ("2006", self.var9.get()),
             ("2007", self.var10.get()),
             ("2008", self.var11.get()),
             ("2009", self.var12.get()),
             ("2010", self.var13.get()),
             ("2011", self.var14.get()),
             ("2012", self.var15.get()),
             ("2013", self.var16.get()),
             ("2014", self.var17.get()),
             ("2015", self.var18.get()),
             ("2016", self.var19.get()),
             ("2017", self.var20.get())]
        print("var1.get type=",type(self.var1.get()))
        self.loadFiles()
        
    def loadFiles(self):
        years_down=[]
        if(len(self.years)>0):
            for i in range(len(self.years)):
                if(self.years[i][1]==1):
                    years_down.append(self.years[i][0])
                    temp=[]
                    r=requests.get('https://raw.githubusercontent.com/gblyth/NEISS/master/NEISS_'+
                                   self.years[i][0]+'Q1.bin')
                    r_data=r.text.split("\n")
                    for row in r_data:
                        temp.append(row.split("\t"))
                    r=requests.get('https://raw.githubusercontent.com/gblyth/NEISS/master/NEISS_'+
                                   self.years[i][0]+'Q2.bin')
                    r_data=r.text.split("\n")
                    for row in range(1,len(r_data)):
                        temp.append(r_data[row].split("\t"))
                    r=requests.get('https://raw.githubusercontent.com/gblyth/NEISS/master/NEISS_'+
                                   self.years[i][0]+'Q3.bin')
                    r_data=r.text.split("\n")
                    for row in range(1,len(r_data)):
                        temp.append(r_data[row].split("\t"))
                    r=requests.get('https://raw.githubusercontent.com/gblyth/NEISS/master/NEISS_'+
                                   self.years[i][0]+'Q4.bin')
                    r_data=r.text.split("\n")
                    for row in range(1,len(r_data)):
                        temp.append(r_data[row].split("\t"))
                    self.data.append(temp)
        print("Years downloaded are:\n",years_down)
        self.data_loaded=True
        self.file_to_dl=True
        self.data_years.set("Years of Data Loaded=\n"+str(years_down))
        self.load_str.set("Datasets Loaded="+str(self.data_loaded))
        self.dl_str.set("File Ready To Download="+str(self.file_to_dl))
        self.master.update_idletasks()
        
    def downloadFiles(self):
        place=askdirectory()
        print("Place=",place)
        
    def checkCase(self):
        case="???"
        print(case)
                
                
    def makeGUI(self):
        years=["1998", "1999", "2000", "2001", "2002", "2003", "2004", "2005", "2006",
              "2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015",
              "2016", "2017"]
#        self.var1=IntVar()

        Checkbutton(self.master, text=years[0], variable=self.var1).grid(row=1, sticky=W)
        Checkbutton(self.master, text=years[1], variable=self.var2).grid(row=2, sticky=W)
        Checkbutton(self.master, text=years[2], variable=self.var3).grid(row=3, sticky=W)
        Checkbutton(self.master, text=years[3], variable=self.var4).grid(row=4, sticky=W)
        Checkbutton(self.master, text=years[4], variable=self.var5).grid(row=5, sticky=W)
        Checkbutton(self.master, text=years[5], variable=self.var6).grid(row=6, sticky=W)
        Checkbutton(self.master, text=years[6], variable=self.var7).grid(row=7, sticky=W)
        Checkbutton(self.master, text=years[7], variable=self.var8).grid(row=8, sticky=W)
        Checkbutton(self.master, text=years[8], variable=self.var9).grid(row=9, sticky=W)
        Checkbutton(self.master, text=years[9], variable=self.var10).grid(row=10, sticky=W)
        Checkbutton(self.master, text=years[10], variable=self.var11).grid(row=11, sticky=W)
        Checkbutton(self.master, text=years[11], variable=self.var12).grid(row=12, sticky=W)
        Checkbutton(self.master, text=years[12], variable=self.var13).grid(row=13, sticky=W)
        Checkbutton(self.master, text=years[13], variable=self.var14).grid(row=14, sticky=W)
        Checkbutton(self.master, text=years[14], variable=self.var15).grid(row=15, sticky=W)
        Checkbutton(self.master, text=years[15], variable=self.var16).grid(row=16, sticky=W)
        Checkbutton(self.master, text=years[16], variable=self.var17).grid(row=17, sticky=W)
        Checkbutton(self.master, text=years[17], variable=self.var18).grid(row=18, sticky=W)
        Checkbutton(self.master, text=years[18], variable=self.var19).grid(row=19, sticky=W)
        Checkbutton(self.master, text=years[19], variable=self.var20).grid(row=20, sticky=W)
        Button(self.master, text="Load Selected Data", command=self.varStates).grid(column=2, row=1)
        Button(self.master, text="Download File", command=self.downloadFiles).grid(column=2, row=2)
        Button(self.master, text="Quit", command=self.master.destroy).grid(column=2, row=3)
        Label(self.master, textvariable=self.load_str).grid(column=3, row=1)
        Label(self.master, textvariable=self.dl_str).grid(column=3, row=2)
        Label(self.master, textvariable=self.data_years).grid(column=3, row=3)
        Label(self.master, text="Date").grid(column=4, row=1)
        Label(self.master, text="Age").grid(column=4, row=2)
        Label(self.master, text="Sex").grid(column=4, row=3)
        Label(self.master, text="Race").grid(column=4, row=4)
        Label(self.master, text="Other_Race").grid(column=4, row=5)
        Label(self.master, text="Body_Part").grid(column=4, row=6)
        Label(self.master, text="Diagnosis").grid(column=4, row=7)
        Label(self.master, text="Other_Diagnosis").grid(column=4, row=8)
        Label(self.master, text="Disposition").grid(column=4, row=9)
        Label(self.master, text="Location").grid(column=4, row=10)
        Label(self.master, text="Fire_Involvement").grid(column=4, row=11)
        Label(self.master, text="Product#1").grid(column=4, row=12)
        Label(self.master, text="Product#2").grid(column=4, row=13)
        Label(self.master, text="Narrative Field").grid(column=4, row=14)
        Label(self.master, text="Stratum").grid(column=4, row=15)
        Label(self.master, text="PSU").grid(column=4, row=16)
        Label(self.master, text="Weight").grid(column=4, row=17)
        Entry(self.master, textvariable=self.entry1, width=34).grid(column=5, row=1)
        Entry(self.master, textvariable=self.entry2).grid(column=5, row=2)
        Entry(self.master, textvariable=self.entry3).grid(column=5, row=3)
        Entry(self.master, textvariable=self.entry4).grid(column=5, row=4)
        Entry(self.master, textvariable=self.entry5).grid(column=5, row=5)
        Entry(self.master, textvariable=self.entry6).grid(column=5, row=6)
        Entry(self.master, textvariable=self.entry7).grid(column=5, row=7)
        Entry(self.master, textvariable=self.entry8).grid(column=5, row=8)
        Entry(self.master, textvariable=self.entry9).grid(column=5, row=9)
        Entry(self.master, textvariable=self.entry10).grid(column=5, row=10)
        Entry(self.master, textvariable=self.entry11).grid(column=5, row=11)
        Entry(self.master, textvariable=self.entry12).grid(column=5, row=12)
        Entry(self.master, textvariable=self.entry13).grid(column=5, row=13)
        Entry(self.master, textvariable=self.entry14).grid(column=5, row=14)
        Entry(self.master, textvariable=self.entry15).grid(column=5, row=15)
        Entry(self.master, textvariable=self.entry16).grid(column=5, row=16)
        Entry(self.master, textvariable=self.entry17).grid(column=5, row=17)
        Button(self.master, text="Submit", command=self.checkCase).grid(column=5, row=18)
        
        mainloop()
        
master=Tk()
neiss_GUI=NEISS_Data_Requester(master)
neiss_GUI.makeGUI()

#r=requests.get('https://raw.githubusercontent.com/gblyth/NEISS/master/NEISS_1998Q1.bin')
#data=r.text.split("\n")
#for i in range(10):
#    print("Line:",i,"is=\n",data[i])
#print(r.text)
# Out:
# ???
